# %% [markdown]
# <a href="https://colab.research.google.com/github/turna1/3D-LLM/blob/main/cisc12w_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Basics of Colab

# %% [markdown]
# # Example 1

# %%
print("Hello Class of  CISC-121 Winter")
#this is an example of print
# Out:
# Hello Class of  CISC-121 Winter

# %%
import time
print(time.ctime())
time.
print(time.ctime())
# Out:
# Fri Jan  9 20:15:37 2026
# Fri Jan  9 20:15:42 2026

# %%
! pip install numpy

# %%
x = 5
print(x/1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-3783051434.py in <cell line: 0>()
#       1 x = 5
# ----> 2 print(x/0)
#
# ZeroDivisionError: division by zero
